# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import cv2
import utils
import preprocess
import detect_answer 
import detect_cross
import math

# %% [markdown]
# # Load image

# %%
plt.rcParams['figure.figsize'] = [8, 8]

# %%
img = cv2.imread('exam_hasBackground.jpg', 0)
plt.imshow(img, cmap='gray')

# %% [markdown]
# # Preprocessor

# %%
blurred = cv2.GaussianBlur(img, (5, 5), 0)

# %%
thresh = preprocess.threshold(blurred)
plt.imshow(thresh, cmap='gray')

# %%
approx,box = preprocess.findContour(thresh)
img = preprocess.turnning(approx,box,img)
plt.imshow(img, cmap='gray')

# %%
binary_img =preprocess.preprocess(img)

# %%
close = utils.closing(binary_img, (2,2))
