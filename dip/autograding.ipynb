# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import cv2
from utils import *
from preprocess import * 
from detect_answer import *
from detect_cross import *

# %%
plt.rcParams['figure.figsize'] = [8, 8]

# %%
img = cv2.imread('exam4.png', 0)
plt.imshow(img, cmap='gray')

# %%
binary_img = preprocess(img, (5,5))

# %%
close = closing(binary_img, (2,2))

# %%
filled = fill_holes(close)

# %%
open = opening(filled, (7,7))

# %%
contours = find_contours(open)

# %%
circle_centers = detect_circle(img, contours, 0.6, 140)
circle_centers
# Out:
# [[53, 926],
#  [50, 841],
#  [45, 795],
#  [344, 709],
#  [341, 639],
#  [40, 576],
#  [32, 519],
#  [29, 370],
#  [25, 314],
#  [333, 215],
#  [217, 143],
#  [184, 143],
#  [157, 143]]

# %%
choices = get_circles_no_cross(circle_centers)

# %%
answers = get_answer(choices)

# %%
right_answers = []
# score = get_score(answers, right_answers)
# print(score)
